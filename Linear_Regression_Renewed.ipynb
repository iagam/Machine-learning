# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import time
import math

# %%
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split

X_R1, y_R1 = make_regression(n_samples = 100, n_features=1,
                            n_informative=1, bias = 150.0,
                            noise = 30, random_state=0)

X_train, X_test, y_train, y_test = train_test_split(X_R1, y_R1, test_size = 0.2, random_state = 0)
print(X_train.shape)
# Out:
# (80, 1)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

linreg = LinearRegression()
linreg.fit(X_train, y_train)

print("Coefficient : ",linreg.coef_)
print("Slope : ",linreg.intercept_)
print("R-squared training score : ", np.round(linreg.score(X_train,y_train)*100,3))
print("R-squared test score : ", np.round(linreg.score(X_test,y_test)*100,3))
# Out:
# Coefficient :  [43.5929738]
# Slope :  147.8365495777098
# R-squared training score :  65.301
# R-squared test score :  61.076

# %%
plt.scatter(X_R1,y_R1,marker="o",c='blue')
plt.plot(X_R1,linreg.coef_*X_R1+linreg.intercept_,c='red')
plt.title('Least-squares linear regression')
plt.xlabel('Feature value (x)')
plt.ylabel('Target value (y)')
plt.show()

# %%
test = [0.05,0.1,0.15,0.20,0.25,0.33] 

for i in test:
    X_train, X_test, y_train, y_test = train_test_split(X_R1, y_R1, test_size = i,random_state=0)
    linreg = LinearRegression()
    linreg.fit(X_train, y_train)
    print(f"Training accuracy at {i} test_size = {linreg.score(X_train,y_train)}")
    print(f"Test accuracy at {i} test_size = {linreg.score(X_test,y_test)}")
    
    plt.plot(i,linreg.score(X_test,y_test),marker="*", c="green")
    plt.plot(i,linreg.score(X_train,y_train),marker = "*", c="red")
    plt.xlabel("Test Size")
    plt.ylabel("R-squared value")
# Out:
# Training accuracy at 0.05 test_size = 0.6269638754765393
# Test accuracy at 0.05 test_size = 0.947700748302191
# Training accuracy at 0.1 test_size = 0.6243070044183834
# Test accuracy at 0.1 test_size = 0.9133396320360895
# Training accuracy at 0.15 test_size = 0.6406469485919705
# Test accuracy at 0.15 test_size = 0.6840384639377808
# Training accuracy at 0.2 test_size = 0.6530078959089367
# Test accuracy at 0.2 test_size = 0.6107643540019796
# Training accuracy at 0.25 test_size = 0.6785950771141656
# Test accuracy at 0.25 test_size = 0.49159615934930306
# Training accuracy at 0.33 test_size = 0.6629077083651601
# Test accuracy at 0.33 test_size = 0.5936412465289143
